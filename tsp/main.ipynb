# %%
from tsp_solver import main

main()
# Out:
# ...
#   TSP SOLVER -- SIMULATED ANNEALING VARIANTS COMPARISON
#   10-Node Symmetric Problem  |  9 SA variants  |  20 runs each
# ...
#
# ...
#   PART A: GLOBAL OPTIMUM  (Exhaustive Enumeration)
# ...
#
#   Enumerating 362,880 tours ...
#   Time     : 0.265 s
#   Tour     : 1 -> 3 -> 7 -> 10 -> 2 -> 8 -> 4 -> 9 -> 6 -> 5 -> 1
#   Distance : 608
#
# ...
#   PART B: RUNNING ALL VARIANTS  (20 independent runs each)
# ...
#   Running V0  Standard (Boltzmann + 2opt + Geometric) ...
#   Running V1  Acceptance: Linear  (P = 1 - d/T) ...
#   Running V2  Acceptance: Discrete (0.8/0.6/0.4) ...
#   Running V3  Neighborhood: Transposition (swap) ...
#   Running V4  Neighborhood: Displacement (insertion) ...
#   Running V5  Cooling: Logarithmic ...
#   Running V6  Cooling: Lundy-Mees ...
#   Running V7  Cooling: Fixed Temperature (T=50) ...
#   Running V8  Reheating (cool on accept, heat on reject) ...
#
#   Total time across all variants: 41.4 s
#
# ...
#   PART C: COMPARATIVE RESULTS TABLE
# ...
#
# ...
